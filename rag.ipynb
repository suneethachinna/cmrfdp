# %%
pip install llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.4 MB/s eta 0:00:00
# ...

# %%
pip install llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 20.0 MB/s eta 0:00:00
# ...

# %%
from llama_index.llms.groq import Groq

# %%
 api_key = "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"

# %%
llm=Groq(model="llama3-70b-8192",api_key = "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")

# %%
llm = Groq(model="llama3-70b-8192", api_key = "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")

# %%
resp = llm.complete("Explain the importance of llm")

# %%
print(resp)
# Out:
# LLMs (Large Language Models) have revolutionized the field of Natural Language Processing (NLP) and have numerous applications in various industries. Here are some of the importance of LLMs:
#
# 1. **Improved Language Understanding**: LLMs have enabled machines to understand human language more accurately, allowing them to process and analyze vast amounts of text data. This has led to significant advancements in applications such as language translation, sentiment analysis, and text summarization.
# 2. **Enhanced Customer Experience**: LLMs are used in chatbots and virtual assistants to provide personalized customer support, helping businesses to improve customer satisfaction and loyalty.
# 3. **Automation of Tasks**: LLMs can automate many tasks, such as data entry, content generation, and language translation, freeing up human resources for more strategic and creative work.
# ...

# %%
from llama_index.core.llms import ChatMessage
messages = [
ChatMessage(
    role="system", content="you are apirate with colorful personality"
),
             ChatMessage(role="user",content="What is your name"),
]
rep =llm.chat(messages)

print(resp)
# Out:
# LLMs (Large Language Models) have revolutionized the field of Natural Language Processing (NLP) and have numerous applications in various industries. Here are some of the importance of LLMs:
#
# 1. **Improved Language Understanding**: LLMs have enabled machines to understand human language more accurately, allowing them to process and analyze vast amounts of text data. This has led to significant advancements in applications such as language translation, sentiment analysis, and text summarization.
# 2. **Enhanced Customer Experience**: LLMs are used in chatbots and virtual assistants to provide personalized customer support, helping businesses to improve customer satisfaction and loyalty.
# 3. **Automation of Tasks**: LLMs can automate many tasks, such as data entry, content generation, and language translation, freeing up human resources for more strategic and creative work.
# ...

# %%
response =llm.stream_complete("Explain the importance of low latency llm")
for r in response:
  print(r.delta, end="")
# Out:
# Low latency in Large Language Models (LLMs) is crucial for several reasons:
#
# 1. **Real-time Interaction**: Low latency enables real-time interaction between humans and AI systems, making conversations feel more natural and responsive. This is particularly important for applications like chatbots, virtual assistants, and voice assistants, where users expect immediate responses.
# 2. **Improved User Experience**: High latency can lead to frustration and disengagement. By reducing latency, LLMs can provide a more seamless and engaging user experience, increasing the likelihood of users returning to the application or service.
# 3. **Enhanced Productivity**: In professional settings, low latency can significantly improve productivity. For example, in language translation or text summarization tasks, rapid response times enable users to work more efficiently and make decisions quickly.
# ...

# %%
pip install llama-index llama-index-embeddings-huggingface llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 91.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import logging
import sys
from google.colab import userdata
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.llms.openai import OpenAI
from llama_index.llms.groq import Groq

# %%
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# !mkdir data
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# --2025-03-13 06:07:42--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.02s
#
# 2025-03-13 06:07:42 (3.30 MB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# ...

# %%
GROQ_API_KEY = "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"

# %%
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# llm = OpenAI(
#     model="gpt-3.5-turbo",
#     api_key=userdata.get('sk-o60aCUo7BIVicqzB9moWRGmmqi1cipD_DxNfLgYvdRT3BlbkFJBEdMcAOAsfbQoVnuEbEMDBjEm8WMrz16hteNIyjqUA')
# )

llm = Groq(
   model="llama3-70b-8192",
   api_key="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"
)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# The author worked on two main things outside of school: writing and programming. He wrote short stories, which he thought were awful, and tried writing programs on an IBM 1401 computer.
